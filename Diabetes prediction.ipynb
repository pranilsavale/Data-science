# %% [markdown]
# # Importing libraries

# %%
import numpy as np
import pandas as pd
import seaborn as sns

# %%
df = pd.read_csv("diabetes.csv")

# %%
df
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6    148.0           72.0             35      0.0  33.6
# 1              1     85.0           66.0             29      0.0  26.6
# 2              8    183.0           64.0              0      0.0  23.3
# 3              1     89.0           66.0             23     94.0  28.1
# 4              0    137.0           40.0             35    168.0  43.1
# ..           ...      ...            ...            ...      ...   ...
# 763           10    101.0           76.0             25    180.0  32.9
# 764            2    122.0           70.0             25      0.0  36.8
# 765            5    121.0           72.0             25    112.0  26.2
# 766            1    126.0           60.0             25      0.0  30.1
# 767            1     93.0           70.0             25      0.0  30.4
#
#      DiabetesPedigreeFunction   Age  Outcome
# 0                       0.627  50.0        1
# ...

# %%
df.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6    148.0           72.0             35      0.0  33.6
# 1            1     85.0           66.0             29      0.0  26.6
# 2            8    183.0           64.0              0      0.0  23.3
# 3            1     89.0           66.0             23     94.0  28.1
# 4            0    137.0           40.0             35    168.0  43.1
#
#    DiabetesPedigreeFunction   Age  Outcome
# 0                     0.627  50.0        1
# 1                     0.351  31.0        0
# 2                     0.672  32.0        1
# 3                     0.167  21.0        0
# 4                     2.288  33.0        1

# %%
df.shape
# Out:
# (768, 9)

# %% [markdown]
# # Data Preprocessing

# %%
# check for null values

# %%
df.isnull().sum()
# Out:
# Pregnancies                 0
# Glucose                     2
# BloodPressure               2
# SkinThickness               0
# Insulin                     2
# BMI                         0
# DiabetesPedigreeFunction    1
# Age                         2
# Outcome                     0
# dtype: int64

# %%
df['Glucose'] = df['Glucose'].fillna(df['Glucose'].median())

# %%
df['BloodPressure'] = df['BloodPressure'].fillna(df['BloodPressure'].median())

# %%
df['Insulin'] = df['Insulin'].fillna(df['Insulin'].median())

# %%
df['DiabetesPedigreeFunction'] = df['DiabetesPedigreeFunction'].fillna(df['DiabetesPedigreeFunction'].median())

# %%
df['Age'] = df['Age'].fillna(df['Age'].median())

# %%
df.isnull().sum()
# Out:
# Pregnancies                 0
# Glucose                     0
# BloodPressure               0
# SkinThickness               0
# Insulin                     0
# BMI                         0
# DiabetesPedigreeFunction    0
# Age                         0
# Outcome                     0
# dtype: int64

# %% [markdown]
# # EDA

# %%
tc = df.corr()

# %%
tc
# Out:
#                           Pregnancies   Glucose  BloodPressure  SkinThickness  \
# Pregnancies                  1.000000  0.131814       0.141236      -0.138610
# Glucose                      0.131814  1.000000       0.154414      -0.017717
# BloodPressure                0.141236  0.154414       1.000000      -0.012751
# SkinThickness               -0.138610 -0.017717      -0.012751       1.000000
# Insulin                     -0.070532  0.300992       0.089656       0.080850
# BMI                          0.017683  0.224300       0.280965       0.068867
# DiabetesPedigreeFunction    -0.032714  0.137942       0.039833       0.025857
# Age                          0.546698  0.249858       0.240238      -0.051961
# Outcome                      0.221898  0.461812       0.065533       0.013548
#
#                            Insulin       BMI  DiabetesPedigreeFunction  \
# Pregnancies              -0.070532  0.017683                 -0.032714
# ...

# %%
sns.heatmap(tc)
# Out:
# <AxesSubplot:>

# %%
sns.pairplot(df)

# %% [markdown]
# # Defining x and y

# %%
df.columns
# Out:
# Index(['Pregnancies', 'Glucose', 'BloodPressure', 'SkinThickness', 'Insulin',
#        'BMI', 'DiabetesPedigreeFunction', 'Age', 'Outcome'],
#       dtype='object')

# %%
x = df[['Pregnancies', 'Glucose', 'BloodPressure', 'SkinThickness', 'Insulin',
       'BMI', 'DiabetesPedigreeFunction', 'Age']]

# %%
y = df[['Outcome']]

# %% [markdown]
# # Model development

# %%
from sklearn.model_selection import train_test_split

# %%
x_train, x_test, y_train, y_test = train_test_split(x,y,test_size = 0.3)

# %% [markdown]
# # Create the pipeline

# %% [markdown]
# ##### To find out which model is good for this  data
# WE will be using Random Forest, SVM, Naive bayes, Logestic regression, Decision Tree classification models

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.svm import LinearSVC
from sklearn.naive_bayes import MultinomialNB
from sklearn.model_selection import cross_val_score

models = [
    RandomForestClassifier(),
    DecisionTreeClassifier(),
    LinearSVC(),
    MultinomialNB(),
    LogisticRegression(),
]
CV = 40
cv_df = pd.DataFrame(index=range(CV * len(models)))

# %%
entries = []
for model in models:
  model_name = model.__class__.__name__
  accuracies = cross_val_score(model, x_train, y_train, scoring='accuracy', cv=CV)
  for fold_idx, accuracy in enumerate(accuracies):
    entries.append((model_name, fold_idx, accuracy))
cv_df = pd.DataFrame(entries, columns=['model_name', 'fold_idx', 'accuracy'])
# Out:
# C:\Users\PRANIL\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:531: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# C:\Users\PRANIL\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:531: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# C:\Users\PRANIL\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:531: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# ...

# %%
cv_df
# Out:
#                  model_name  fold_idx  accuracy
# 0    RandomForestClassifier         0  0.714286
# 1    RandomForestClassifier         1  0.857143
# 2    RandomForestClassifier         2  0.857143
# 3    RandomForestClassifier         3  0.785714
# 4    RandomForestClassifier         4  0.642857
# ..                      ...       ...       ...
# 195      LogisticRegression        35  0.769231
# 196      LogisticRegression        36  0.846154
# 197      LogisticRegression        37  0.923077
# 198      LogisticRegression        38  0.615385
# 199      LogisticRegression        39  0.692308
#
# [200 rows x 3 columns]

# %%
cv_df.groupby('model_name').mean()
# Out:
#                         fold_idx  accuracy
# model_name
# DecisionTreeClassifier      19.5  0.697253
# LinearSVC                   19.5  0.594368
# LogisticRegression          19.5  0.749588
# MultinomialNB               19.5  0.596016
# RandomForestClassifier      19.5  0.752473

# %% [markdown]
# ### From above pipeline it indicates that we will use RandomForest classifier as a final model as it shows high accuracy

# %%
# model devlopement

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
model = RandomForestClassifier()

# %%
from sklearn.model_selection import train_test_split

# %%
x_train, x_test, y_train, y_test = train_test_split(x,y,test_size = 0.3)

# %%
model.fit(x_train,y_train)
# Out:
# <ipython-input-42-4719cf73997a>:1: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   model.fit(x_train,y_train)
# RandomForestClassifier()

# %%
y_pred = model.predict(x_test)

# %%
from sklearn import metrics

# %%
metrics.accuracy_score(y_test,y_pred)
# Out:
# 0.8095238095238095

# %% [markdown]
# # Random forest classifier model is giving accuracy of 80.95%

# %% [markdown]
# ## To increase accuracy we can do following:-
# #### 1. feature selection
# #### 2. removing outliers
# #### 3. hyper tuning

# %% [markdown]
# # Feature selection

# %%
# feature selection with 6 features

# %%
from sklearn.feature_selection import RFE

# %%
x.shape
# Out:
# (768, 8)

# %%
x.columns
# Out:
# Index(['Pregnancies', 'Glucose', 'BloodPressure', 'SkinThickness', 'Insulin',
#        'BMI', 'DiabetesPedigreeFunction', 'Age'],
#       dtype='object')

# %%
rfe = RFE(model,6)
# Out:
# C:\Users\PRANIL\anaconda3\lib\site-packages\sklearn\utils\validation.py:67: FutureWarning: Pass n_features_to_select=6 as keyword args. From version 0.25 passing these as positional arguments will result in an error
#   warnings.warn("Pass {} as keyword args. From version 0.25 "

# %%
fit = rfe.fit(x_train,y_train)
# Out:
# C:\Users\PRANIL\anaconda3\lib\site-packages\sklearn\feature_selection\_rfe.py:196: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X[:, features], y)
# C:\Users\PRANIL\anaconda3\lib\site-packages\sklearn\feature_selection\_rfe.py:196: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X[:, features], y)
# C:\Users\PRANIL\anaconda3\lib\site-packages\sklearn\feature_selection\_rfe.py:231: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   self.estimator_.fit(X[:, features], y)

# %%
fit.ranking_
# Out:
# array([2, 1, 1, 3, 1, 1, 1, 1])

# %%
x_new1 = x[['Glucose', 'BloodPressure', 'Insulin',
       'BMI', 'DiabetesPedigreeFunction', 'Age']]

# %%
x_new1_train, x_new1_test, y_train, y_test = train_test_split(x_new1,y,test_size = 0.3)

# %%
model1 = model

# %%
model1
# Out:
# RandomForestClassifier()

# %%
model1.fit(x_new1_train,y_train)
# Out:
# <ipython-input-56-6502e7438b75>:1: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   model1.fit(x_new1_train,y_train)
# RandomForestClassifier()

# %%
y_pred1= model1.predict(x_new1_test)

# %%
cm = metrics.confusion_matrix(y_test,y_pred)

# %%
cm
# Out:
# array([[115,  42],
#        [ 53,  21]], dtype=int64)

# %%
accuracy = metrics.accuracy_score(y_test,y_pred1)

# %%
accuracy
# Out:
# 0.7662337662337663

# %% [markdown]
# ##### It gives accuracy less than 80.95% hence regecting 6 features

# %%
# feature selection with 5 features

# %%
x.columns
# Out:
# Index(['Pregnancies', 'Glucose', 'BloodPressure', 'SkinThickness', 'Insulin',
#        'BMI', 'DiabetesPedigreeFunction', 'Age'],
#       dtype='object')

# %%
rfe = RFE(model,5)
# Out:
# C:\Users\PRANIL\anaconda3\lib\site-packages\sklearn\utils\validation.py:67: FutureWarning: Pass n_features_to_select=5 as keyword args. From version 0.25 passing these as positional arguments will result in an error
#   warnings.warn("Pass {} as keyword args. From version 0.25 "

# %%
fit = rfe.fit(x_train,y_train)
# Out:
# C:\Users\PRANIL\anaconda3\lib\site-packages\sklearn\feature_selection\_rfe.py:196: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X[:, features], y)
# C:\Users\PRANIL\anaconda3\lib\site-packages\sklearn\feature_selection\_rfe.py:196: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X[:, features], y)
# C:\Users\PRANIL\anaconda3\lib\site-packages\sklearn\feature_selection\_rfe.py:196: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X[:, features], y)
# ...

# %%
fit.ranking_
# Out:
# array([3, 1, 1, 4, 2, 1, 1, 1])

# %%
x.columns
# Out:
# Index(['Pregnancies', 'Glucose', 'BloodPressure', 'SkinThickness', 'Insulin',
#        'BMI', 'DiabetesPedigreeFunction', 'Age'],
#       dtype='object')

# %%
x_new2 = x[['Glucose', 'BloodPressure',
       'BMI', 'DiabetesPedigreeFunction', 'Age']]

# %%
x_new2_train, x_new2_test, y_train, y_test = train_test_split(x_new2,y,test_size = 0.3)

# %%
model2 = model

# %%
model
# Out:
# RandomForestClassifier()

# %%
model2.fit(x_new2_train,y_train)
# Out:
# <ipython-input-72-2a35197fc4d6>:1: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   model2.fit(x_new2_train,y_train)
# RandomForestClassifier()

# %%
y_pred2= model2.predict(x_new2_test)

# %%
cm = metrics.confusion_matrix(y_test,y_pred)

# %%
cm
# Out:
# array([[108,  47],
#        [ 60,  16]], dtype=int64)

# %%
accuracy = metrics.accuracy_score(y_test,y_pred2)

# %%
accuracy
# Out:
# 0.7748917748917749

# %% [markdown]
# ##### It gives accuracy less than 80.95% hence regecting 5 features

# %%
# feature selection with 4 features

# %%
x.columns
# Out:
# Index(['Pregnancies', 'Glucose', 'BloodPressure', 'SkinThickness', 'Insulin',
#        'BMI', 'DiabetesPedigreeFunction', 'Age'],
#       dtype='object')

# %%
rfe = RFE(model,4)
# Out:
# C:\Users\PRANIL\anaconda3\lib\site-packages\sklearn\utils\validation.py:67: FutureWarning: Pass n_features_to_select=4 as keyword args. From version 0.25 passing these as positional arguments will result in an error
#   warnings.warn("Pass {} as keyword args. From version 0.25 "

# %%
fit = rfe.fit(x_train,y_train)
# Out:
# C:\Users\PRANIL\anaconda3\lib\site-packages\sklearn\feature_selection\_rfe.py:196: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X[:, features], y)
# C:\Users\PRANIL\anaconda3\lib\site-packages\sklearn\feature_selection\_rfe.py:196: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X[:, features], y)
# C:\Users\PRANIL\anaconda3\lib\site-packages\sklearn\feature_selection\_rfe.py:196: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X[:, features], y)
# ...

# %%
fit.ranking_
# Out:
# array([4, 1, 1, 5, 3, 1, 1, 2])

# %%
x.columns
# Out:
# Index(['Pregnancies', 'Glucose', 'BloodPressure', 'SkinThickness', 'Insulin',
#        'BMI', 'DiabetesPedigreeFunction', 'Age'],
#       dtype='object')

# %%
x_new3 = x[['Glucose', 'BloodPressure',
       'BMI', 'DiabetesPedigreeFunction']]

# %%
x_new3_train, x_new3_test, y_train, y_test = train_test_split(x_new3,y,test_size = 0.3)

# %%
model3 = model

# %%
model
# Out:
# RandomForestClassifier()

# %%
model3.fit(x_new3_train,y_train)
# Out:
# <ipython-input-88-8d9fe9d91f10>:1: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   model3.fit(x_new3_train,y_train)
# RandomForestClassifier()

# %%
y_pred3= model3.predict(x_new3_test)

# %%
cm = metrics.confusion_matrix(y_test,y_pred)

# %%
cm
# Out:
# array([[113,  36],
#        [ 55,  27]], dtype=int64)

# %%
accuracy = metrics.accuracy_score(y_test,y_pred3)

# %%
accuracy
# Out:
# 0.7575757575757576

# %% [markdown]
# ##### It gives accuracy less than 80.95% hence regecting 4 features

# %% [markdown]
# # No need of doing feature selection as it is not increasing accuracy

# %% [markdown]
# ## Finalize
#
# model :: pipeline
#
# features :: No features selected

# %% [markdown]
# ## Removing outliers

# %%
Q1_df = df.quantile(0.25)
Q3_df = df.quantile(0.75)
IQR = Q3_df - Q1_df
print(IQR)
# Out:
# Pregnancies                   5.0000
# Glucose                      41.0000
# BloodPressure                18.0000
# SkinThickness                 0.0000
# Insulin                     126.2500
# BMI                           9.3000
# DiabetesPedigreeFunction      0.3825
# Age                          16.2500
# Outcome                       1.0000
# dtype: float64

# %%
df_out = df[~((df < (Q1_df - 1.5 * IQR)) |(df > (Q3_df + 1.5 * IQR))).any(axis=1)]
df_out.shape
# Out:
# (602, 9)

# %%
df.shape
# Out:
# (602, 9)

# %%
df_out.columns
# Out:
# Index(['Pregnancies', 'Glucose', 'BloodPressure', 'SkinThickness', 'Insulin',
#        'BMI', 'DiabetesPedigreeFunction', 'Age', 'Outcome'],
#       dtype='object')

# %%
## using all features

# %%
x_out = df_out[['Pregnancies', 'Glucose', 'BloodPressure', 'SkinThickness', 'Insulin',
       'BMI', 'DiabetesPedigreeFunction', 'Age']]

# %%
y_out = df_out[['Outcome']]

# %%
# split the data
x_out_train, x_out_test, y_out_train, y_out_test = train_test_split(x_out,y_out,test_size = 0.3)

# %%
# that model we will take, that we have finilized for good accuracy

# %%
model
# Out:
# RandomForestClassifier()

# %%
model.fit(x_out_train,y_out_train)
# Out:
# <ipython-input-192-3778796eaa8d>:1: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   model.fit(x_out_train,y_out_train)
# RandomForestClassifier()

# %%
y_out_pred = model1.predict(x_out_test)

# %%
cm = metrics.confusion_matrix(y_out_test,y_out_pred)

# %%
cm
# Out:
# array([[110,  22],
#        [ 18,  31]], dtype=int64)

# %%
accuracy = metrics.accuracy_score(y_out_test,y_out_pred)

# %%
accuracy
# Out:
# 0.7790055248618785

# %% [markdown]
# # Accuracy is lower han 80.95% hence no need of removing outliers

# %% [markdown]
# # Conclusion
# - no need to remove outliers
# - finilized
#     - data = df
#     - no features selection
#     - model

# %% [markdown]
# ## Find out the best parameters to improve accuracy

# %% [markdown]
# ## Hyper tuning

# %%
model
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-1f8a688cae5d> in <module>
# ----> 1 model
#
# NameError: name 'model' is not defined

# %%
from sklearn.model_selection import GridSearchCV

# %%
#n_estimators

n_estimators = [100,200,300,400]

# %%
hyperparameters = dict(n_estimators=n_estimators)

# %%
hyperparameters
# Out:
# {'n_estimators': [100, 200, 300, 400]}

# %%
# Create grid search using 5-fold cross validation
clf = GridSearchCV(model1, hyperparameters, cv=2, verbose=0)

# %%
clf
# Out:
# GridSearchCV(cv=2, estimator=RandomForestClassifier(),
#              param_grid={'n_estimators': [100, 200, 300, 400]})

# %%
best_model = clf.fit(x_train, y_train)
# Out:
# C:\Users\PRANIL\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:531: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# C:\Users\PRANIL\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:531: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# C:\Users\PRANIL\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:531: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# ...

# %%
print('Best n_estimators:', best_model.best_estimator_.get_params()['n_estimators'])
# Out:
# Best n_estimators: 200

# %%
model_x = RandomForestClassifier(n_estimators = 200)

# %%
model_x
# Out:
# RandomForestClassifier(n_estimators=200)

# %%
model_x.fit(x_train,y_train)
# Out:
# <ipython-input-214-22755651bce5>:1: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   model_x.fit(x_train,y_train)
# RandomForestClassifier(n_estimators=200)

# %%
y_pred_x = model_x.predict(x_test)

# %%
accuracy = metrics.accuracy_score(y_pred_x,y_test)

# %%
accuracy
# Out:
# 0.670995670995671

# %% [markdown]
# ## Hypertuning reduces accuracy hence no need of hypertuning

# %% [markdown]
# ## Conclusion:
#
# #### Model selected is Random Forest Classifier and its accuracy is 80.95%.
#
# #### Feature selection, Hypertuning and removing outliers reduces accuracy hence it should not be done.
